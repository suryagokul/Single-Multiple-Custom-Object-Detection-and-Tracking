# %% [markdown]
# <a href="https://colab.research.google.com/github/suryagokul/Single-Multiple-Custom-Object-Detection-and-Tracking/blob/master/People_Counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/emasterclassacademy/Single-Multiple-Custom-Object-Detection-and-Tracking.git
# Out:
# Cloning into 'Single-Multiple-Custom-Object-Detection-and-Tracking'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 72 (delta 9), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (72/72), done.

# %%
# %cd /content/Single-Multiple-Custom-Object-Detection-and-Tracking/
# Out:
# /content/Single-Multiple-Custom-Object-Detection-and-Tracking

# %%
# %cd weights
# Out:
# /content/Single-Multiple-Custom-Object-Detection-and-Tracking/weights

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-04-02 04:23:36--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  71.4MB/s    in 3.5s
#
# 2021-04-02 04:23:40 (66.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# %cd ..
# Out:
# /content/Single-Multiple-Custom-Object-Detection-and-Tracking

# %%
# !python convert.py
# Out:
# 2021-04-02 04:23:58.027305: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-02 04:24:00.326814: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-02 04:24:00.327995: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-02 04:24:00.338904: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-04-02 04:24:00.338944: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (d67980fbe37a): /proc/driver/nvidia/version does not exist
# ...

# %%
# !python object_tracker.py
# Out:
# 2021-04-02 10:32:11.778421: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-02 10:32:13.564260: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-02 10:32:13.568962: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-02 10:32:13.580585: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-04-02 10:32:13.580638: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (d67980fbe37a): /proc/driver/nvidia/version does not exist
# ...

# %% [markdown]
# `If there is an error cannot connect to X server then try to comment out cv2 imshow,destroyallwindows,release functions.`
#
# `If there is an error regarding KeyError: "The name 'net/images:0' refers to a Tensor which does not exist. then Try to change "net/%s:0" => "%s:0" 83 & 85 lines in tools/generate_detections.py`

# %%
from google.colab.patches import cv2_imshow
